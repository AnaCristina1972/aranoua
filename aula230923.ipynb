# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaCristina1972/aranoua/blob/main/aula230923.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 1
print(a)
# Out:
# 1

# %%
cls

# %%
import pandas as pd

# %%
df = pd.read_csv('athlete_events.csv')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df = pd.read_csv('municipios.csv')
df.head(1000)
# Out:
#      codigo_ibge                   nome  latitude  longitude  capital  \
# 0        5200050        Abadia de Goiás -16.75730   -49.4412        0
# 1        3100104    Abadia dos Dourados -18.48310   -47.3916        0
# 2        5200100              Abadiânia -16.19700   -48.7057        0
# 3        3100203                 Abaeté -19.15510   -45.4444        0
# 4        1500107             Abaetetuba  -1.72183   -48.8788        0
# ..           ...                    ...       ...        ...      ...
# 995      3509809  Campos Novos Paulista -22.60200   -49.9987        0
# 996      2302701           Campos Sales  -7.06761   -40.3687        0
# 997      5204953          Campos Verdes -14.24420   -49.6528        0
# 998      2603603              Camutanga  -7.40545   -35.2664        0
# 999      3111903             Cana Verde -21.02320   -45.1801        0
#
#      codigo_uf
# 0           52
# 1           31
# 2           52
# 3           31
# 4           15
# ..         ...
# ...

# %%
df_num2 = pd.read_csv('municipios_2.csv')
df.head()
# Out:
#    codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0      5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1      3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2      5200100            Abadiânia -16.19700   -48.7057        0         52
# 3      3100203               Abaeté -19.15510   -45.4444        0         31
# 4      1500107           Abaetetuba  -1.72183   -48.8788        0         15

# %%
df_num2.describe()
# Out:
#        codigo_ibge;nome;latitude;longitude;capital;codigo_uf
# count                                                5570
# unique                                               5570
# top        5200050;Abadia de Goiás;-16.7573;-49.4412;0;52
# freq                                                    1

# %%
df_num2 = pd.read_csv('municipios_2.csv', sep=';')
df.head()
# Out:
#    codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0      5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1      3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2      5200100            Abadiânia -16.19700   -48.7057        0         52
# 3      3100203               Abaeté -19.15510   -45.4444        0         31
# 4      1500107           Abaetetuba  -1.72183   -48.8788        0         15

# %%
df.tail()
# Out:
#       codigo_ibge         nome  latitude  longitude  capital  codigo_uf
# 5565      2933604  Xique-Xique -10.82300   -42.7245        0         29
# 5566      2517407       Zabelê  -8.07901   -37.1057        0         25
# 5567      3557154     Zacarias -21.05060   -50.0552        0         35
# 5568      2114007      Zé Doca  -3.27014   -45.6553        0         21
# 5569      4219853       Zortéa -27.45210   -51.5520        0         42

# %%
print
# Out:
# <function print>

# %%
print(df.shape)
# Out:
# (5570, 6)

# %%
print(df.columns) #retorno listas
# Out:
# Index(['codigo_ibge', 'nome', 'latitude', 'longitude', 'capital', 'codigo_uf'], dtype='object')

# %%
df['codigo_ibge'] # lista a coluna
# Out:
# 0       5200050
# 1       3100104
# 2       5200100
# 3       3100203
# 4       1500107
#          ...
# 5565    2933604
# 5566    2517407
# 5567    3557154
# 5568    2114007
# 5569    4219853
# Name: codigo_ibge, Length: 5570, dtype: int64

# %%
df[['codigo_ibge', 'nome']]
# Out:
#       codigo_ibge                 nome
# 0         5200050      Abadia de Goiás
# 1         3100104  Abadia dos Dourados
# 2         5200100            Abadiânia
# 3         3100203               Abaeté
# 4         1500107           Abaetetuba
# ...           ...                  ...
# 5565      2933604          Xique-Xique
# 5566      2517407               Zabelê
# 5567      3557154             Zacarias
# 5568      2114007              Zé Doca
# 5569      4219853               Zortéa
#
# [5570 rows x 2 columns]

# %%
df.query("nome=='Manaus'")
# Out:
#       codigo_ibge    nome  latitude  longitude  capital  codigo_uf
# 2885      1302603  Manaus  -3.11866   -60.0212        1         13

# %%
df.query("nome=='1'")
# Out:
# Empty DataFrame
# Columns: [codigo_ibge, nome, latitude, longitude, capital, codigo_uf]
# Index: []

# %%
df.query("nome==1")
# Out:
# Empty DataFrame
# Columns: [codigo_ibge, nome, latitude, longitude, capital, codigo_uf]
# Index: []

# %%
df.query("capital == 1") #consulta
# Out:
#       codigo_ibge            nome   latitude  longitude  capital  codigo_uf
# 294       2800308         Aracaju -10.909100   -37.0677        1         28
# 580       1501402           Belém  -1.455400   -48.4898        1         15
# 592       3106200  Belo Horizonte -19.910200   -43.9266        1         31
# 642       1400100       Boa Vista   2.823840   -60.6753        1         14
# 755       5300108        Brasília -15.779500   -47.9297        1         53
# 972       5002704    Campo Grande -20.448600   -54.6295        1         50
# 1491      5103403          Cuiabá -15.601000   -56.0974        1         51
# 1508      4106902        Curitiba -25.419500   -49.2646        1         41
# 1812      4205407   Florianópolis -27.594500   -48.5477        1         42
# 1831      2304400       Fortaleza  -3.716640   -38.5423        1         23
# 1927      5208707         Goiânia -16.686400   -49.2643        1         52
# ...

# %%
#loc e iloc - métodos de referencia para linhas e colunas
df.loc[0:10,['nome', 'codigo_ibge']]
# Out:
#                    nome  codigo_ibge
# 0       Abadia de Goiás      5200050
# 1   Abadia dos Dourados      3100104
# 2             Abadiânia      5200100
# 3                Abaeté      3100203
# 4            Abaetetuba      1500107
# 5               Abaiara      2300101
# 6                Abaíra      2900108
# 7                 Abaré      2900207
# 8                Abatiá      4100103
# 9         Abdon Batista      4200051
# 10      Abel Figueiredo      1500131

# %%
print(df.loc[1050])
# Out:
# codigo_ibge         3510203
# nome           Capão Bonito
# latitude           -24.0113
# longitude          -48.3482
# capital                   0
# codigo_uf                35
# Name: 1050, dtype: object

# %%
df.loc[1050:2000] #loc filtra linhas/indices
# Out:
#       codigo_ibge                 nome  latitude  longitude  capital  \
# 1050      3510203         Capão Bonito -24.01130   -48.3482        0
# 1051      4304622  Capão Bonito do Sul -28.12540   -51.3961        0
# 1052      4304630       Capão da Canoa -29.76420   -50.0282        0
# 1053      4304655        Capão do Cipó -28.93120   -54.5558        0
# 1054      4304663        Capão do Leão -31.75650   -52.4889        0
# ...           ...                  ...       ...        ...      ...
# 1996      5209200                Guapó -16.82970   -49.5345        0
# 1997      4309407              Guaporé -28.83990   -51.8895        0
# 1998      4109104            Guaporema -23.34020   -52.7786        0
# 1999      3517703                Guará -20.43020   -47.8236        0
# 2000      2506301            Guarabira  -6.85064   -35.4850        0
#
#       codigo_uf
# 1050         35
# 1051         43
# 1052         43
# 1053         43
# 1054         43
# ...         ...
# ...

# %%
df.loc[[100, 200, 300, 400]]
# Out:
#      codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 100      2100303        Aldeias Altas  -4.62621   -43.4689        0         21
# 200      3501707  Américo Brasiliense -21.72880   -48.1147        0         35
# 300      2902104                Araci -11.32530   -38.9584        0         29
# 400      3503802       Artur Nogueira -22.57270   -47.1727        0         35

# %%
df_num2.loc[["Manaus", "Parintins", "Itacoatiara"]] #search set index
# Out:
#              codigo_ibge  latitude  longitude  capital  codigo_uf
# nome
# Manaus           1302603  -3.11866   -60.0212        1         13
# Parintins        1303403  -2.63741   -56.7290        0         13
# Itacoatiara      1301902  -3.13861   -58.4449        0         13

# %%
df.groupby(by="codigo_uf").size()
# Out:
# codigo_uf
# 11     52
# 12     22
# 13     62
# 14     15
# 15    144
# 16     16
# 17    139
# 21    217
# 22    224
# 23    184
# 24    167
# 25    223
# 26    185
# 27    102
# 28     75
# 29    417
# 31    853
# 32     78
# 33     92
# 35    645
# 41    399
# 42    295
# 43    497
# 50     79
# 51    141
# 52    246
# 53      1
# dtype: int64

# %%
df.iloc[0]
# Out:
# codigo_ibge            5200050
# nome           Abadia de Goiás
# latitude              -16.7573
# longitude             -49.4412
# capital                      0
# codigo_uf                   52
# Name: 0, dtype: object

# %%
df.iloc[-1]
# Out:
# codigo_ibge    4219853
# nome            Zortéa
# latitude      -27.4521
# longitude      -51.552
# capital              0
# codigo_uf           42
# Name: 5569, dtype: object

# %%
df.iloc[:, 0] #todas as linhas da primeira coluna
# Out:
# 0       5200050
# 1       3100104
# 2       5200100
# 3       3100203
# 4       1500107
#          ...
# 5565    2933604
# 5566    2517407
# 5567    3557154
# 5568    2114007
# 5569    4219853
# Name: codigo_ibge, Length: 5570, dtype: int64

# %%
df.iloc[:, 0] #todas as linhas da primeira coluna
# Out:
# 0       5200050
# 1       3100104
# 2       5200100
# 3       3100203
# 4       1500107
#          ...
# 5565    2933604
# 5566    2517407
# 5567    3557154
# 5568    2114007
# 5569    4219853
# Name: codigo_ibge, Length: 5570, dtype: int64

# %%
df.iloc[0:10, 0:2]
# Out:
#    codigo_ibge                 nome
# 0      5200050      Abadia de Goiás
# 1      3100104  Abadia dos Dourados
# 2      5200100            Abadiânia
# 3      3100203               Abaeté
# 4      1500107           Abaetetuba
# 5      2300101              Abaiara
# 6      2900108               Abaíra
# 7      2900207                Abaré
# 8      4100103               Abatiá
# 9      4200051        Abdon Batista

# %%
# !pip install matplotlib

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
df['latitude'].hist()
# Out:
# <AxesSubplot:>

# %%
df['longitude'].hist()
# Out:
# <AxesSubplot:>

# %%
df_oli = pd.read_csv('london.csv')
df_oli.describe() #dados estaticos das colunas numeridas
# Out:
#               Total           Age       Height       Weight
# count  10384.000000  10384.000000  9823.000000  9104.000000
# mean       0.052196     26.068856   176.907869    72.852812
# std        0.250149      5.440561    11.295433    16.067462
# min        0.000000     13.000000   132.000000    36.000000
# 25%        0.000000     22.000000   169.000000    61.000000
# 50%        0.000000     25.000000   177.000000    70.000000
# 75%        0.000000     29.000000   185.000000    81.000000
# max        5.000000     71.000000   221.000000   218.000000

# %%
df_oli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10384 entries, 0 to 10383
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Total   10384 non-null  int64
#  1   Sport   10384 non-null  object
#  2   Age     10384 non-null  int64
#  3   Height  9823 non-null   float64
#  4   Weight  9104 non-null   float64
#  5   Sex     10384 non-null  object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 486.9+ KB

# %%
df_oli.head()
# Out:
#    Total      Sport  Age  Height  Weight Sex
# 0      0       Judo   23   170.0    60.0   M
# 1      0  Athletics   33   193.0   125.0   M
# 2      0  Athletics   30   187.0    76.0   M
# 3      0     Boxing   24     NaN     NaN   M
# 4      0  Athletics   26   178.0    85.0   F

# %%
df_oli.groupby("Age").size() #filtro
# Out:
# Age
# 13      1
# 14      7
# 15     26
# 16     66
# 17    124
# 18    246
# 19    336
# 20    492
# 21    649
# 22    793
# 23    890
# 24    838
# 25    847
# 26    774
# 27    775
# 28    614
# 29    586
# 30    500
# 31    386
# 32    335
# 33    242
# 34    184
# 35    138
# 36    119
# 37     82
# 38     49
# 39     60
# 40     38
# 41     32
# 42     27
# 43     28
# 44     16
# 45     11
# 46     15
# 47      7
# 48      9
# 49     10
# 50      7
# 51      5
# 52      5
# 53      3
# 54      3
# 56      3
# 57      2
# 58      1
# 65      2
# 71      1
# dtype: int64

# %%
df_oli.Age.value_counts()
# Out:
# 23    890
# 25    847
# 24    838
# 22    793
# 27    775
# 26    774
# 21    649
# 28    614
# 29    586
# 30    500
# 20    492
# 31    386
# 19    336
# 32    335
# 18    246
# 33    242
# 34    184
# 35    138
# 17    124
# 36    119
# 37     82
# 16     66
# 39     60
# 38     49
# 40     38
# 41     32
# 43     28
# 42     27
# 15     26
# 44     16
# 46     15
# 45     11
# 49     10
# 48      9
# 50      7
# 47      7
# 14      7
# 52      5
# 51      5
# 56      3
# 54      3
# 53      3
# 57      2
# 65      2
# 58      1
# 71      1
# 13      1
# Name: Age, dtype: int64

# %%
df_est = pd.read_csv('estados.csv')
df_est
# Out:
#     codigo_uf  uf                 nome
# 0          11  RO             Rondônia
# 1          12  AC                 Acre
# 2          13  AM             Amazonas
# 3          14  RR              Roraima
# 4          15  PA                 Pará
# 5          16  AP                Amapá
# 6          17  TO            Tocantins
# 7          21  MA             Maranhão
# 8          22  PI                Piauí
# 9          23  CE                Ceará
# 10         24  RN  Rio Grande do Norte
# 11         25  PB              Paraíba
# 12         26  PE           Pernambuco
# 13         27  AL              Alagoas
# 14         28  SE              Sergipe
# 15         29  BA                Bahia
# 16         31  MG         Minas Gerais
# 17         32  ES       Espírito Santo
# 18         33  RJ       Rio de Janeiro
# 19         35  SP            São Paulo
# 20         41  PR               Paraná
# 21         42  SC       Santa Catarina
# 22         43  RS    Rio Grande do Sul
# ...

# %%
df_estmun = df.merge(df_est, how='inner', on = 'codigo_uf') #junta
df_estmun
# Out:
#       codigo_ibge              nome_x  latitude  longitude  capital  \
# 0         5200050     Abadia de Goiás  -16.7573   -49.4412        0
# 1         5200100           Abadiânia  -16.1970   -48.7057        0
# 2         5200134             Acreúna  -17.3960   -50.3749        0
# 3         5200159           Adelândia  -16.4127   -50.1657        0
# 4         5200175  Água Fria de Goiás  -14.9778   -47.7823        0
# ...           ...                 ...       ...        ...      ...
# 5565      3306107             Valença  -22.2445   -43.7129        0
# 5566      3306156           Varre-Sai  -20.9276   -41.8701        0
# 5567      3306206           Vassouras  -22.4059   -43.6686        0
# 5568      3306305       Volta Redonda  -22.5202   -44.0996        0
# 5569      5300108            Brasília  -15.7795   -47.9297        1
#
#       codigo_uf  uf            nome_y
# 0            52  GO             Goiás
# 1            52  GO             Goiás
# ...

# %%
# !pip install lxml

# %%
tab_am = pd.read_html('https://en.wikipedia.org/wiki/Amazonas_(Brazilian_state)')
tab_am
# Out:
# [                                             Amazonas  \
#  0                                               State
#  1                 Estado do AmazonasState of Amazonas
#  2   .mw-parser-output .ib-settlement-cols{text-ali...
#  3   Motto(s): Iustitia et Aequalitas (Latin) "Just...
#  4                            Anthem: Hino do Amazonas
#  5                                                 NaN
#  6   Coordinates: .mw-parser-output .geo-default,.m...
#  7                                             Country
#  8                            Capital and largest city
#  9                                          Government
#  10                                         • Governor
#  11                                    • Vice Governor
#  12                                         • Senators
#  13                                               Area
#  14                                            • Total
#  15                                             • Rank
# ...

# %%
print(f'Total de tabelas: {len(tab_am)}')
# Out:
# Total de tabelas: 21

# %%
tab_am = pd.read_html('https://en.wikipedia.org/wiki/Amazonas_(Brazilian_state)', match='Historical population')
tab_am
# Out:
# [             Year           Pop.             ±%
#  0            1872          57610              —
#  1            1890         147915        +156.8%
#  2            1900         249756         +68.9%
#  3            1920         363166         +45.4%
#  4            1940         438008         +20.6%
#  5            1950         514099         +17.4%
#  6            1960         708459         +37.8%
#  7            1970         955235         +34.8%
#  8            1980        1430089         +49.7%
#  9            1991        2103243         +47.1%
#  10           2000        2813085         +33.7%
#  11           2010        3480917         +23.7%
#  12  sources: IBGE  sources: IBGE  sources: IBGE]

# %%
tab_am[0]
# Out:
#              Year           Pop.             ±%
# 0            1872          57610              —
# 1            1890         147915        +156.8%
# 2            1900         249756         +68.9%
# 3            1920         363166         +45.4%
# 4            1940         438008         +20.6%
# 5            1950         514099         +17.4%
# 6            1960         708459         +37.8%
# 7            1970         955235         +34.8%
# 8            1980        1430089         +49.7%
# 9            1991        2103243         +47.1%
# 10           2000        2813085         +33.7%
# 11           2010        3480917         +23.7%
# 12  sources: IBGE  sources: IBGE  sources: IBGE

# %%
df_pop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\IFAM_C~1\AppData\Local\Temp/ipykernel_10100/2304223749.py in <module>
# ----> 1 df_pop
#
# NameError: name 'df_pop' is not defined

# %%
df_pop_am = df_pop_am[0]
df_pop_am
# Out:
#              Year           Pop.             ±%
# 0            1872          57610              —
# 1            1890         147915        +156.8%
# 2            1900         249756         +68.9%
# 3            1920         363166         +45.4%
# 4            1940         438008         +20.6%
# 5            1950         514099         +17.4%
# 6            1960         708459         +37.8%
# 7            1970         955235         +34.8%
# 8            1980        1430089         +49.7%
# 9            1991        2103243         +47.1%
# 10           2000        2813085         +33.7%
# 11           2010        3480917         +23.7%
# 12  sources: IBGE  sources: IBGE  sources: IBGE

# %%
df_pop_am = df_pop_am[:12]
df_pop_am
# Out:
#     Year     Pop.       ±%
# 0   1872    57610        —
# 1   1890   147915  +156.8%
# 2   1900   249756   +68.9%
# 3   1920   363166   +45.4%
# 4   1940   438008   +20.6%
# 5   1950   514099   +17.4%
# 6   1960   708459   +37.8%
# 7   1970   955235   +34.8%
# 8   1980  1430089   +49.7%
# 9   1991  2103243   +47.1%
# 10  2000  2813085   +33.7%
# 11  2010  3480917   +23.7%

# %%
df_pop_am['Year'].astype('int')
df_pop_am['Pop.'].astype('int')
# Out:
# 0       57610
# 1      147915
# 2      249756
# 3      363166
# 4      438008
# 5      514099
# 6      708459
# 7      955235
# 8     1430089
# 9     2103243
# 10    2813085
# 11    3480917
# Name: Pop., dtype: int32

# %% [markdown]
# # Nova seção

# %%
# !pip install opencv-python pillow scikit-image
